# %%
import pandas as pd

# %%
dict1={'Name':['priyang','mitesh','krishna','vedant','parshv','trisha','archana'],
       'Marks':[98,89,99,87,90,83,99],
       'Gender':['male','male','male','male','male','female','female']}

df=pd.DataFrame(dict1)
print(df)
# Out:
#       Name  Marks  Gender
# 0  priyang     98    male
# 1   mitesh     89    male
# 2  krishna     99    male
# 3   vedant     87    male
# 4   parshv     90    male
# 5   trisha     83  female
# 6  archana     99  female

# %% [markdown]
# **1.Display Top 3 Rows of the Dataset**

# %%
df.head(3)
# Out:
#       Name  Marks Gender
# 0  priyang     98   male
# 1   mitesh     89   male
# 2  krishna     99   male

# %% [markdown]
# **2.Check Last 3 Rows of the Dataset**

# %%
df.tail(3)
# Out:
#       Name  Marks  Gender
# 4   parshv     90    male
# 5   trisha     83  female
# 6  archana     99  female

# %% [markdown]
# **3.Find Shape of our dataset(number of rows & number of coloumns)**

# %%
df.shape
# Out:
# (7, 3)

# %%
print("number of rows",df.shape[0])
print("number of coloumns",df.shape[1])
# Out:
# number of rows 7
# number of coloumns 3

# %% [markdown]
# **4. Getting Information About Our Dataset Like Total Number Rows,
# Total Number of Columns, Datatypes of Each Column And Memory Requirement**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %% [markdown]
# **5.Check Null Values In The Dataset**

# %%
df.isnull().sum()
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %% [markdown]
# **6.Get Overall Statistics About The Dataframe**

# %%
df.describe(include='all')
# Out:
#            Name      Marks Gender
# count         7   7.000000      7
# unique        7        NaN      2
# top     priyang        NaN   male
# freq          1        NaN      5
# mean        NaN  92.142857    NaN
# std         NaN   6.491753    NaN
# min         NaN  83.000000    NaN
# 25%         NaN  88.000000    NaN
# 50%         NaN  90.000000    NaN
# 75%         NaN  98.500000    NaN
# max         NaN  99.000000    NaN

# %% [markdown]
# **7.find unique value from the gender coloumn**

# %%
df
# Out:
#       Name  Marks  Gender
# 0  priyang     98    male
# 1   mitesh     89    male
# 2  krishna     99    male
# 3   vedant     87    male
# 4   parshv     90    male
# 5   trisha     83  female
# 6  archana     99  female

# %%
df['Gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# **8.find the number of unique values from the gender coloumn**

# %%
df['Gender'].nunique()
# Out:
# 2

# %% [markdown]
# **9.display count of unique values in gender coloumn**

# %%
df['Gender'].value_counts()
# Out:
# Gender
# male      5
# female    2
# Name: count, dtype: int64

# %% [markdown]
# **10.find total number of students having marks between 90 to 100(inclusive) using between method**

# %%
df[df['Marks']>=90]
# Out:
#       Name  Marks  Gender
# 0  priyang     98    male
# 2  krishna     99    male
# 4   parshv     90    male
# 6  archana     99  female

# %%
len(df[(df['Marks'] >= 90) & (df['Marks'] <= 100)])
# Out:
# 4

# %%
sum(df['Marks'].between(90,100))
# Out:
# 4

# %% [markdown]
# **11.find average marks**

# %%
df
# Out:
#       Name  Marks  Gender
# 0  priyang     98    male
# 1   mitesh     89    male
# 2  krishna     99    male
# 3   vedant     87    male
# 4   parshv     90    male
# 5   trisha     83  female
# 6  archana     99  female

# %%
df['Marks'].mean()
# Out:
# np.float64(92.14285714285714)

# %% [markdown]
# **12.apply method**

# %%
def marks(x):
  return x//2

# %%
df['half_marks']=df['Marks'].apply(marks)

# %%
df
# Out:
#       Name  Marks  Gender  half_marks
# 0  priyang     98    male          49
# 1   mitesh     89    male          44
# 2  krishna     99    male          49
# 3   vedant     87    male          43
# 4   parshv     90    male          45
# 5   trisha     83  female          41
# 6  archana     99  female          49

# %%
df['Marks'].apply(lambda x:x//2)
# Out:
# 0    49
# 1    44
# 2    49
# 3    43
# 4    45
# 5    41
# 6    49
# Name: Marks, dtype: int64

# %%
df['name_length']=df['Name'].apply(len)
df
# Out:
#       Name  Marks  Gender  half_marks  name_length
# 0  priyang     98    male          49            7
# 1   mitesh     89    male          44            6
# 2  krishna     99    male          49            7
# 3   vedant     87    male          43            6
# 4   parshv     90    male          45            6
# 5   trisha     83  female          41            6
# 6  archana     99  female          49            7

# %% [markdown]
# **13.Map Function**

# %%
df
# Out:
#       Name  Marks  Gender  half_marks  name_length
# 0  priyang     98    male          49            7
# 1   mitesh     89    male          44            6
# 2  krishna     99    male          49            7
# 3   vedant     87    male          43            6
# 4   parshv     90    male          45            6
# 5   trisha     83  female          41            6
# 6  archana     99  female          49            7

# %%
df['male_female']=df['Gender'].map({'male':1,'female':0})
df
# Out:
#       Name  Marks  Gender  half_marks  name_length  male_female
# 0  priyang     98    male          49            7            1
# 1   mitesh     89    male          44            6            1
# 2  krishna     99    male          49            7            1
# 3   vedant     87    male          43            6            1
# 4   parshv     90    male          45            6            1
# 5   trisha     83  female          41            6            0
# 6  archana     99  female          49            7            0

# %% [markdown]
# **14.drop the coloumn**

# %%
df
# Out:
#       Name  Marks  Gender  half_marks  name_length  male_female
# 0  priyang     98    male          49            7            1
# 1   mitesh     89    male          44            6            1
# 2  krishna     99    male          49            7            1
# 3   vedant     87    male          43            6            1
# 4   parshv     90    male          45            6            1
# 5   trisha     83  female          41            6            0
# 6  archana     99  female          49            7            0

# %%
df.drop('male_female',axis=1)
# Out:
#       Name  Marks  Gender  half_marks  name_length
# 0  priyang     98    male          49            7
# 1   mitesh     89    male          44            6
# 2  krishna     99    male          49            7
# 3   vedant     87    male          43            6
# 4   parshv     90    male          45            6
# 5   trisha     83  female          41            6
# 6  archana     99  female          49            7

# %%
df.drop(['male_female', 'name_length'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1323779631.py in <cell line: 0>()
# ----> 1 df.drop(['male_female', 'name_length'], axis=1, inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df
# Out:
#       Name  Marks  Gender  half_marks
# 0  priyang     98    male          49
# 1   mitesh     89    male          44
# 2  krishna     99    male          49
# 3   vedant     87    male          43
# 4   parshv     90    male          45
# 5   trisha     83  female          41
# 6  archana     99  female          49

# %% [markdown]
# **15.print name of the coloumns**

# %%
print(df.columns)
# Out:
# Index(['Name', 'Marks', 'Gender', 'half_marks'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# **16.sort the dataframe as per the marks coloumn**

# %%
df
# Out:
#       Name  Marks  Gender  half_marks
# 0  priyang     98    male          49
# 1   mitesh     89    male          44
# 2  krishna     99    male          49
# 3   vedant     87    male          43
# 4   parshv     90    male          45
# 5   trisha     83  female          41
# 6  archana     99  female          49

# %%
df.sort_values(by=['Marks','Gender'],ascending=False)
# Out:
#       Name  Marks  Gender  half_marks
# 2  krishna     99    male          49
# 6  archana     99  female          49
# 0  priyang     98    male          49
# 4   parshv     90    male          45
# 1   mitesh     89    male          44
# 3   vedant     87    male          43
# 5   trisha     83  female          41

# %% [markdown]
# **17.display name and marks of female students**

# %%
df[df['Gender']=='female'] [['Name','Marks']]
# Out:
#       Name  Marks
# 5   trisha     83
# 6  archana     99

# %%
df[df['Gender'].isin(['female'])] [['Name','Marks']]
# Out:
#       Name  Marks
# 5   trisha     83
# 6  archana     99

# %%
from google.colab import drive
drive.mount('/content/drive')
